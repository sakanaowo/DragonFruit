# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !wget https://github.com/scls/assets/releases/download/v8.2.0/scl.pt
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !rm mydataset.yaml # nếu có file thì xóa
# !echo 'train: /kaggle/input/thanhlong4/thanhlong4/train' >> mydataset.yaml
# !echo 'test: /kaggle/input/thanhlong4/thanhlong4/train' >> mydataset.yaml
# !echo 'val: /kaggle/input/thanhlong4/thanhlong4/train' >> mydataset.yaml
# !echo 'nc: 3' >> mydataset.yaml
# !echo "names: ['thoibe', 'namcanh','thanthu']" >> mydataset.yaml
# Out:
# 'rm' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
from scls.scl import SCL
os.environ["WANDB_MODE"] = "disabled"
model = SCL("scl.pt")

results = model.train(data="mydataset.yaml", epochs=100)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 from scls.scl import SCL
#       3 os.environ["WANDB_MODE"] = "disabled"
#       4 model = SCL("scl.pt")
#
# ImportError: cannot import name 'SCL' from 'scls.scl' (unknown location)

# %%
# !scl task=detect mode=predict model="/kaggle/working/runs/detect/train/weights/best.pt" source="https://taydojsc.com.vn/files/uploads/benh-dom-nau-tren-thanh-long.png"
# Out:
# 'scl' is not recognized as an internal or external command,
# operable program or batch file.
